# %% [markdown]
# ## VGGNet type net

# %%
import os
import numpy as np
import seaborn as sns
import cv2 as cv

import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
tree_types = os.listdir('../data/image data/train')
X = []
y = []
val_x = []
val_y = []

for tree in tree_types:
    tree_path = os.path.join('../data/image data/train', tree)
    tree_disease_types = os.listdir(tree_path)

    for disease in tree_disease_types:
        img_name = os.listdir(os.path.join(tree_path, disease))

        for img in img_name:
            image_path = os.path.join(tree_path, disease, img)
            image = cv.resize(cv.imread(image_path), dsize=(96, 96))
            X.append(image)
            y.append([tree, disease])

for tree in tree_types:
    tree_path = os.path.join('../data/image data/validation', tree)
    tree_disease_types = os.listdir(tree_path)

    for disease in tree_disease_types:
        img_name = os.listdir(os.path.join(tree_path, disease))

        for img in img_name:
            image_path = os.path.join(tree_path, disease, img)
            image = cv.resize(cv.imread(image_path), dsize=(96, 96))
            X.append(image)
            y.append([tree, disease])

# %%
X = np.asarray(X)
val_x = np.asarray(val_x)
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(y)
val_y = mlb.transform(val_y)
generator = ImageDataGenerator(rescale=1. / 255,
                               rotation_range=15,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True,
                               validation_split=0.2
                               )

# %%
y.shape
# Out:
# (41810, 39)

# %%
train_gen = generator.flow(X, y, batch_size=32, subset='training')
val_gen = generator.flow(X, y, batch_size=32, subset='validation')

# %%
check_pointer = ModelCheckpoint(filepath='checkpoints/exp_conv_9.hdf5',
                                save_best_only=True)

early_stop = EarlyStopping(monitor='val_loss',
                           restore_best_weights=True,
                           patience=20,
                           min_delta=0)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=20)

# %%
base_units = 32
weight_decay = 1e-4
exp_conv = Sequential()

exp_conv.add(InputLayer(input_shape=(96, 96, 3)))

# conv 1
exp_conv.add(Conv2D(filters=base_units, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# conv 2
exp_conv.add(Conv2D(filters=base_units, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# pool and dropout
exp_conv.add(MaxPooling2D(pool_size=(2, 2)))
exp_conv.add(Dropout(0.2))

# conv 3
exp_conv.add(Conv2D(filters=base_units * 2, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# conv 4
exp_conv.add(Conv2D(filters=base_units * 2, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# pool and dropout
exp_conv.add(MaxPooling2D(pool_size=(2, 2)))
exp_conv.add(Dropout(0.3))

# conv 5
exp_conv.add(Conv2D(filters=base_units * 4, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# conv 6
exp_conv.add(Conv2D(filters=base_units * 4, kernel_size=(3, 3), kernel_regularizer=l2(weight_decay), padding='same',
                    activation=relu))
exp_conv.add(BatchNormalization())

# pool and dropout
exp_conv.add(MaxPooling2D(pool_size=(2, 2)))
exp_conv.add(Dropout(0.4))

# fully connected
exp_conv.add(Flatten())
exp_conv.add(Dense(units=39, activation=sigmoid))

exp_conv.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 96, 96, 3)        12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 96, 96, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         147584
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 39)                20007
#
# =================================================================
# Total params: 1,160,019
# Trainable params: 1,160,013
# Non-trainable params: 6
# _________________________________________________________________

# %%
plot_model(exp_conv,
           to_file='../models/exp_conv_5.png',
           show_shapes=True,
           show_dtype=True,
           show_layer_names=True)

# %%
exp_conv.compile(optimizer=Adam(lr=0.0001, decay=1e-6),
                 loss=binary_crossentropy,
                 metrics=[Recall(), Precision(), 'accuracy', AUC()])

history = exp_conv.fit(train_gen,
                       epochs=200,
                       validation_data=val_gen,
                       callbacks=[check_pointer, early_stop],
                       shuffle=True)
# Out:
# Epoch 1/200
# 1046/1046 [==============================] - 59s 50ms/step - loss: 0.0999 - recall: 0.4686 - precision: 0.7770 - accuracy: 0.2650 - auc: 0.9453 - val_loss: 0.1363 - val_recall: 0.3279 - val_precision: 0.5731 - val_accuracy: 0.3027 - val_auc: 0.9083 - lr: 0.0010
# Epoch 2/200
# 1046/1046 [==============================] - 50s 48ms/step - loss: 0.0481 - recall: 0.7508 - precision: 0.8780 - accuracy: 0.3598 - auc: 0.9882 - val_loss: 0.1041 - val_recall: 0.4839 - val_precision: 0.6927 - val_accuracy: 0.4162 - val_auc: 0.9497 - lr: 0.0010
# Epoch 3/200
# 1046/1046 [==============================] - 52s 50ms/step - loss: 0.0359 - recall: 0.8201 - precision: 0.9049 - accuracy: 0.3697 - auc: 0.9932 - val_loss: 0.0937 - val_recall: 0.5729 - val_precision: 0.6796 - val_accuracy: 0.4097 - val_auc: 0.9589 - lr: 0.0010
# Epoch 4/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0298 - recall: 0.8543 - precision: 0.9211 - accuracy: 0.3850 - auc: 0.9946 - val_loss: 0.0790 - val_recall: 0.6393 - val_precision: 0.7818 - val_accuracy: 0.5294 - val_auc: 0.9701 - lr: 0.0010
# Epoch 5/200
# 1046/1046 [==============================] - 52s 50ms/step - loss: 0.0264 - recall: 0.8730 - precision: 0.9321 - accuracy: 0.3881 - auc: 0.9952 - val_loss: 0.0646 - val_recall: 0.6994 - val_precision: 0.7924 - val_accuracy: 0.5022 - val_auc: 0.9806 - lr: 0.0010
# Epoch 6/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0239 - recall: 0.8843 - precision: 0.9372 - accuracy: 0.4053 - auc: 0.9961 - val_loss: 0.0683 - val_recall: 0.6735 - val_precision: 0.7895 - val_accuracy: 0.4473 - val_auc: 0.9776 - lr: 0.0010
# Epoch 7/200
# 1046/1046 [==============================] - 52s 49ms/step - loss: 0.0215 - recall: 0.8956 - precision: 0.9422 - accuracy: 0.4016 - auc: 0.9965 - val_loss: 0.0658 - val_recall: 0.6813 - val_precision: 0.8355 - val_accuracy: 0.5216 - val_auc: 0.9783 - lr: 0.0010
# Epoch 8/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0211 - recall: 0.9005 - precision: 0.9452 - accuracy: 0.4065 - auc: 0.9964 - val_loss: 0.0609 - val_recall: 0.7088 - val_precision: 0.8494 - val_accuracy: 0.4939 - val_auc: 0.9807 - lr: 0.0010
# Epoch 9/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0190 - recall: 0.9095 - precision: 0.9511 - accuracy: 0.4263 - auc: 0.9970 - val_loss: 0.0685 - val_recall: 0.6956 - val_precision: 0.8332 - val_accuracy: 0.5727 - val_auc: 0.9752 - lr: 0.0010
# Epoch 10/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0185 - recall: 0.9103 - precision: 0.9504 - accuracy: 0.4267 - auc: 0.9971 - val_loss: 0.0556 - val_recall: 0.7257 - val_precision: 0.8830 - val_accuracy: 0.5145 - val_auc: 0.9819 - lr: 0.0010
# Epoch 11/200
# 1046/1046 [==============================] - 52s 50ms/step - loss: 0.0179 - recall: 0.9140 - precision: 0.9529 - accuracy: 0.4291 - auc: 0.9972 - val_loss: 0.0586 - val_recall: 0.7540 - val_precision: 0.8447 - val_accuracy: 0.5960 - val_auc: 0.9826 - lr: 0.0010
# Epoch 12/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0172 - recall: 0.9178 - precision: 0.9565 - accuracy: 0.4254 - auc: 0.9972 - val_loss: 0.0575 - val_recall: 0.7296 - val_precision: 0.8747 - val_accuracy: 0.5246 - val_auc: 0.9816 - lr: 0.0010
# Epoch 13/200
# 1046/1046 [==============================] - 55s 53ms/step - loss: 0.0168 - recall: 0.9201 - precision: 0.9563 - accuracy: 0.4358 - auc: 0.9972 - val_loss: 0.0511 - val_recall: 0.7449 - val_precision: 0.8938 - val_accuracy: 0.5755 - val_auc: 0.9860 - lr: 0.0010
# Epoch 14/200
# 1046/1046 [==============================] - 54s 51ms/step - loss: 0.0155 - recall: 0.9271 - precision: 0.9598 - accuracy: 0.4502 - auc: 0.9976 - val_loss: 0.0552 - val_recall: 0.7356 - val_precision: 0.8843 - val_accuracy: 0.5694 - val_auc: 0.9835 - lr: 0.0010
# Epoch 15/200
# 1046/1046 [==============================] - 54s 52ms/step - loss: 0.0162 - recall: 0.9242 - precision: 0.9576 - accuracy: 0.4555 - auc: 0.9974 - val_loss: 0.0571 - val_recall: 0.7425 - val_precision: 0.8883 - val_accuracy: 0.5722 - val_auc: 0.9830 - lr: 0.0010
# Epoch 16/200
# 1046/1046 [==============================] - 57s 54ms/step - loss: 0.0154 - recall: 0.9285 - precision: 0.9622 - accuracy: 0.4600 - auc: 0.9974 - val_loss: 0.0621 - val_recall: 0.7347 - val_precision: 0.8644 - val_accuracy: 0.4972 - val_auc: 0.9783 - lr: 0.0010
# Epoch 17/200
# 1046/1046 [==============================] - 61s 58ms/step - loss: 0.0155 - recall: 0.9268 - precision: 0.9602 - accuracy: 0.4732 - auc: 0.9974 - val_loss: 0.0513 - val_recall: 0.7639 - val_precision: 0.9044 - val_accuracy: 0.6320 - val_auc: 0.9849 - lr: 0.0010
# Epoch 18/200
# 1046/1046 [==============================] - 59s 56ms/step - loss: 0.0154 - recall: 0.9272 - precision: 0.9598 - accuracy: 0.4927 - auc: 0.9974 - val_loss: 0.0616 - val_recall: 0.7688 - val_precision: 0.8339 - val_accuracy: 0.5792 - val_auc: 0.9796 - lr: 0.0010
# Epoch 19/200
# 1046/1046 [==============================] - 58s 55ms/step - loss: 0.0153 - recall: 0.9283 - precision: 0.9616 - accuracy: 0.4840 - auc: 0.9974 - val_loss: 0.0666 - val_recall: 0.7319 - val_precision: 0.8004 - val_accuracy: 0.5629 - val_auc: 0.9748 - lr: 0.0010
# Epoch 20/200
# 1046/1046 [==============================] - 55s 52ms/step - loss: 0.0142 - recall: 0.9332 - precision: 0.9630 - accuracy: 0.4894 - auc: 0.9976 - val_loss: 0.0581 - val_recall: 0.7545 - val_precision: 0.8911 - val_accuracy: 0.5917 - val_auc: 0.9805 - lr: 0.0010
# Epoch 21/200
# 1046/1046 [==============================] - 54s 52ms/step - loss: 0.0158 - recall: 0.9281 - precision: 0.9613 - accuracy: 0.4896 - auc: 0.9971 - val_loss: 0.0655 - val_recall: 0.7251 - val_precision: 0.8754 - val_accuracy: 0.5270 - val_auc: 0.9756 - lr: 0.0010
# Epoch 22/200
# 1046/1046 [==============================] - 54s 52ms/step - loss: 0.0141 - recall: 0.9341 - precision: 0.9641 - accuracy: 0.4957 - auc: 0.9976 - val_loss: 0.0760 - val_recall: 0.7090 - val_precision: 0.8472 - val_accuracy: 0.5227 - val_auc: 0.9700 - lr: 0.0010
# Epoch 23/200
# 1046/1046 [==============================] - 54s 52ms/step - loss: 0.0146 - recall: 0.9323 - precision: 0.9651 - accuracy: 0.4976 - auc: 0.9974 - val_loss: 0.0532 - val_recall: 0.7599 - val_precision: 0.9072 - val_accuracy: 0.5761 - val_auc: 0.9824 - lr: 0.0010
# Epoch 24/200
# 1046/1046 [==============================] - 55s 52ms/step - loss: 0.0147 - recall: 0.9329 - precision: 0.9647 - accuracy: 0.5070 - auc: 0.9973 - val_loss: 0.0729 - val_recall: 0.7368 - val_precision: 0.8636 - val_accuracy: 0.5710 - val_auc: 0.9746 - lr: 0.0010
# Epoch 25/200
# 1046/1046 [==============================] - 53s 50ms/step - loss: 0.0140 - recall: 0.9353 - precision: 0.9649 - accuracy: 0.5314 - auc: 0.9975 - val_loss: 0.0616 - val_recall: 0.7464 - val_precision: 0.8821 - val_accuracy: 0.6043 - val_auc: 0.9781 - lr: 0.0010
# Epoch 26/200
# 1046/1046 [==============================] - 57s 55ms/step - loss: 0.0148 - recall: 0.9324 - precision: 0.9648 - accuracy: 0.5378 - auc: 0.9973 - val_loss: 0.0612 - val_recall: 0.7581 - val_precision: 0.8904 - val_accuracy: 0.6489 - val_auc: 0.9795 - lr: 0.0010
# Epoch 27/200
# 1046/1046 [==============================] - 54s 52ms/step - loss: 0.0143 - recall: 0.9343 - precision: 0.9653 - accuracy: 0.5346 - auc: 0.9975 - val_loss: 0.0578 - val_recall: 0.7569 - val_precision: 0.8977 - val_accuracy: 0.6498 - val_auc: 0.9806 - lr: 0.0010
# Epoch 28/200
# 1046/1046 [==============================] - 56s 53ms/step - loss: 0.0121 - recall: 0.9437 - precision: 0.9697 - accuracy: 0.5632 - auc: 0.9980 - val_loss: 0.0563 - val_recall: 0.7715 - val_precision: 0.8761 - val_accuracy: 0.6778 - val_auc: 0.9812 - lr: 0.0010
# Epoch 29/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0137 - recall: 0.9366 - precision: 0.9671 - accuracy: 0.5406 - auc: 0.9975 - val_loss: 0.0610 - val_recall: 0.7550 - val_precision: 0.8988 - val_accuracy: 0.6611 - val_auc: 0.9786 - lr: 0.0010
# Epoch 30/200
# 1046/1046 [==============================] - 57s 54ms/step - loss: 0.0146 - recall: 0.9319 - precision: 0.9657 - accuracy: 0.5366 - auc: 0.9973 - val_loss: 0.0781 - val_recall: 0.7524 - val_precision: 0.8892 - val_accuracy: 0.6793 - val_auc: 0.9737 - lr: 0.0010
# Epoch 31/200
# 1046/1046 [==============================] - 54s 51ms/step - loss: 0.0152 - recall: 0.9307 - precision: 0.9655 - accuracy: 0.5303 - auc: 0.9970 - val_loss: 0.0670 - val_recall: 0.7409 - val_precision: 0.8830 - val_accuracy: 0.5433 - val_auc: 0.9766 - lr: 0.0010
# Epoch 32/200
# 1046/1046 [==============================] - 54s 51ms/step - loss: 0.0132 - recall: 0.9381 - precision: 0.9697 - accuracy: 0.5471 - auc: 0.9976 - val_loss: 0.0547 - val_recall: 0.7619 - val_precision: 0.9083 - val_accuracy: 0.6718 - val_auc: 0.9829 - lr: 0.0010
# Epoch 33/200
# 1046/1046 [==============================] - 53s 51ms/step - loss: 0.0130 - recall: 0.9392 - precision: 0.9692 - accuracy: 0.5397 - auc: 0.9977 - val_loss: 0.0655 - val_recall: 0.7529 - val_precision: 0.8959 - val_accuracy: 0.5967 - val_auc: 0.9770 - lr: 0.0010

# %%
figure, axes = plt.subplots(nrows=1, ncols=3, figsize=[18, 6], dpi=300)
axes = axes.ravel()
epochs = list(range(49))

sns.lineplot(x=epochs, y=history.history['loss'], ax=axes[0], label='loss')
sns.lineplot(x=epochs, y=history.history['val_loss'], ax=axes[0], label='val loss')
sns.lineplot(x=epochs, y=history.history['precision'], ax=axes[1], label='precision')
sns.lineplot(x=epochs, y=history.history['val_precision'], ax=axes[1], label='val precision')
sns.lineplot(x=epochs, y=history.history['recall'], color='#025918', ax=axes[1], label='recall')
sns.lineplot(x=epochs, y=history.history['val_recall'], color='#D9B504', ax=axes[1], label='val recall')
sns.lineplot(x=epochs, y=history.history['accuracy'], ax=axes[2], label='accuracy')
sns.lineplot(x=epochs, y=history.history['val_accuracy'], ax=axes[2], label='val accuracy')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('loss')
axes[1].set_xlabel('epoch')
axes[1].set_ylabel('precision and recall')
axes[2].set_xlabel('epoch')
axes[2].set_ylabel('accuracy')
plt.savefig('exp_1_1_conv_train_history.png')
plt.show()

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=[12, 6], dpi=300)
axes = axes.ravel()

sns.lineplot(x=epochs, y=history.history['lr'], ax=axes[0], label='learning rate')
sns.lineplot(x=history.history['lr'], y=history.history['val_accuracy'], ax=axes[1], label='accuracy & lr')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('learning rate')
axes[1].set_xlabel('learning rate')
axes[1].set_ylabel('accuracy')

plt.savefig('AlexNet_base_conv_lr_history.png')
plt.show()
